# %% [markdown]
# # Import packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Import, format, and view data

# %%
# Tutorial this lab is based on -- great spot to start if you want to go further

# Import csv
with open('Pokemon.csv', encoding="utf8", errors='ignore') as f:
    poke_df = pd.read_csv(f)

# Delete index column
del poke_df['#']

# %%
poke_df.head()
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# 0     45      1      False
# 1     60      2      False
# 2     80      3      False
# 3     65      1      False
# 4     80      2      False

# %%
print(poke_df.shape)
poke_df.describe()
# Out:
# (151, 12)
#            Total          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  151.00000  151.000000  151.000000  151.000000  151.000000  151.000000
# mean   407.07947   64.211921   72.549669   68.225166   67.139073   66.019868
# std     99.74384   28.590117   26.596162   26.916704   28.534199   24.197926
# min    195.00000   10.000000    5.000000    5.000000   15.000000   20.000000
# 25%    320.00000   45.000000   51.000000   50.000000   45.000000   49.000000
# 50%    405.00000   60.000000   70.000000   65.000000   65.000000   65.000000
# 75%    490.00000   80.000000   90.000000   84.000000   87.500000   80.000000
# max    680.00000  250.000000  134.000000  180.000000  154.000000  125.000000
#
#             Speed       Stage
# count  151.000000  151.000000
# mean    68.933775    1.582781
# std     26.746880    0.676832
# min     15.000000    1.000000
# 25%     46.500000    1.000000
# 50%     70.000000    1.000000
# 75%     90.000000    2.000000
# max    140.000000    3.000000

# %%
print("{0:<10} {1:<20} {2}".format("VARIABLE","UNIQUE VALUES","NAs"))
for col in poke_df.columns:
    print("{0:<10} {1:<20} {2}".format(col, poke_df[col].nunique(), poke_df[col].isna().sum()))
# Out:
# VARIABLE   UNIQUE VALUES        NAs
# Name       150                  0
# Type 1     15                   0
# Type 2     11                   84
# Total      74                   0
# HP         42                   0
# Attack     46                   0
# Defense    44                   0
# Sp. Atk    34                   0
# Sp. Def    29                   0
# Speed      42                   0
# Stage      3                    0
# Legendary  2                    0

# %%
selected_cols =['Total','HP','Attack','Defense','Sp. Atk','Sp. Def','Speed']
g = sns.PairGrid(poke_df[selected_cols], diag_sharey=False)
g.map_lower(sns.kdeplot, color='g')
g.map_upper(sns.scatterplot, color='g')
g.map_diag(sns.kdeplot, lw=2,color='g')

# %% [markdown]
# # Histograms

# %%
# Histogram (or Distribution plot)
x = poke_df['HP']
sns.distplot(x, color='g');

# %%
# Split HP histogram by stage
by_stage = []
for stage in poke_df['Stage'].unique():
    by_stage.append(poke_df[poke_df['Stage'] == stage])
by_stage
# Out:
# [           Name    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
#  0     Bulbasaur     Grass  Poison    318   45      49       49       65
#  3    Charmander      Fire     NaN    309   39      52       43       60
#  6      Squirtle     Water     NaN    314   44      48       65       50
#  9      Caterpie       Bug     NaN    195   45      30       35       20
#  12       Weedle       Bug  Poison    195   40      35       30       20
#  ..          ...       ...     ...    ...  ...     ...      ...      ...
#  144      Zapdos  Electric  Flying    580   90      90       85      125
#  145     Moltres      Fire  Flying    580   90     100       90      125
#  146     Dratini    Dragon     NaN    300   41      64       45       50
#  149      Mewtwo   Psychic     NaN    680  106     110       90      154
#  150         Mew   Psychic     NaN    600  100     100      100      100
#
#       Sp. Def  Speed  Stage  Legendary
#  0         65     45      1      False
#  3         50     65      1      False
#  6         64     43      1      False
#  9         20     45      1      False
#  12        20     50      1      False
#  ..       ...    ...    ...        ...
#  144       90    100      1       True
#  145       85     90      1       True
#  146       50     50      1      False
#  149       90    130      1       True
#  150      100    100      1      False
#
#  [79 rows x 12 columns],
#             Name    Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
#  1       Ivysaur     Grass   Poison    405   60      62       63       80
#  4    Charmeleon      Fire      NaN    405   58      64       58       80
#  7     Wartortle     Water      NaN    405   59      63       80       65
#  10      Metapod       Bug      NaN    205   50      20       55       25
#  13       Kakuna       Bug   Poison    205   45      25       50       25
#  16    Pidgeotto    Normal   Flying    349   63      60       55       50
#  19     Raticate    Normal      NaN    413   55      81       60       50
#  21       Fearow    Normal   Flying    442   65      90       65       61
#  23        Arbok    Poison      NaN    438   60      85       69       65
#  25       Raichu  Electric      NaN    485   60      90       55       90
#  27    Sandslash    Ground      NaN    450   75     100      110       45
#  29     Nidorina    Poison      NaN    365   70      62       67       55
#  32     Nidorino    Poison      NaN    365   61      72       57       55
#  35     Clefable     Fairy      NaN    483   95      70       73       95
#  37    Ninetales      Fire      NaN    505   73      76       75       81
#  39   Wigglytuff    Normal    Fairy    435  140      70       45       85
#  41       Golbat    Poison   Flying    455   75      80       70       65
#  43        Gloom     Grass   Poison    395   60      65       70       85
#  46     Parasect       Bug    Grass    405   60      95       80       60
#  48     Venomoth       Bug   Poison    450   70      65       60       90
#  50      Dugtrio    Ground      NaN    405   35      80       50       50
#  52      Persian    Normal      NaN    440   65      70       60       65
#  54      Golduck     Water      NaN    500   80      82       78       95
#  56     Primeape  Fighting      NaN    455   65     105       60       60
#  58     Arcanine      Fire      NaN    555   90     110       80      100
#  60    Poliwhirl     Water      NaN    385   65      65       65       50
#  63      Kadabra   Psychic      NaN    400   40      35       30      120
#  66      Machoke  Fighting      NaN    405   80     100       70       50
#  69   Weepinbell     Grass   Poison    390   65      90       50       85
#  72   Tentacruel     Water   Poison    515   80      70       65       80
#  74     Graveler      Rock   Ground    390   55      95      115       45
#  77     Rapidash      Fire      NaN    500   65     100       70       80
#  79      Slowbro     Water  Psychic    490   95      75      110      100
#  81     Magneton  Electric    Steel    465   50      60       95      120
#  84       Dodrio    Normal   Flying    460   60     110       70       60
#  86      Dewgong     Water      Ice    475   90      70       80       70
#  88          Muk    Poison      NaN    500  105     105       75       65
#  90     Cloyster     Water      Ice    525   50      95      180       85
#  92      Haunter     Ghost   Poison    405   45      50       45      115
#  96        Hypno   Psychic      NaN    483   85      73       70       73
#  98      Kingler     Water      NaN    475   55     130      115       50
#  100   Electrode  Electric      NaN    480   60      50       70       80
#  102   Exeggutor     Grass  Psychic    520   95      95       85      125
#  104     Marowak    Ground      NaN    425   60      80      110       50
#  109     Weezing    Poison      NaN    490   65      90      120       85
#  111      Rhydon    Ground     Rock    485  105     130      120       45
#  116      Seadra     Water      NaN    440   55      65       95       95
#  118     Seaking     Water      NaN    450   80      92       65       65
#  120     Starmie     Water  Psychic    520   60      75       85      100
#  129    Gyarados     Water   Flying    540   95     125       79       60
#  133    Vaporeon     Water      NaN    525  130      65       60      110
#  134     Jolteon  Electric      NaN    525   65      65       60      110
#  135     Flareon      Fire      NaN    525   65     130       60       95
#  138     Omastar      Rock    Water    495   70      60      125      115
#  140    Kabutops      Rock    Water    495   60     115      105       65
#  147   Dragonair    Dragon      NaN    420   61      84       65       70
#
#       Sp. Def  Speed  Stage  Legendary
#  1         80     60      2      False
#  4         65     80      2      False
#  7         80     58      2      False
#  10        25     30      2      False
#  13        25     35      2      False
#  16        50     71      2      False
#  19        70     97      2      False
#  21        61    100      2      False
#  23        79     80      2      False
#  25        80    110      2      False
#  27        55     65      2      False
#  29        55     56      2      False
#  32        55     65      2      False
#  35        90     60      2      False
#  37       100    100      2      False
#  39        50     45      2      False
#  41        75     90      2      False
#  43        75     40      2      False
#  46        80     30      2      False
#  48        75     90      2      False
#  50        70    120      2      False
#  52        65    115      2      False
#  54        80     85      2      False
#  56        70     95      2      False
#  58        80     95      2      False
#  60        50     90      2      False
#  63        70    105      2      False
#  66        60     45      2      False
#  69        45     55      2      False
#  72       120    100      2      False
#  74        45     35      2      False
#  77        80    105      2      False
#  79        80     30      2      False
#  81        70     70      2      False
#  84        60    100      2      False
#  86        95     70      2      False
#  88       100     50      2      False
#  90        45     70      2      False
#  92        55     95      2      False
#  96       115     67      2      False
#  98        50     75      2      False
#  100       80    140      2      False
#  102       65     55      2      False
#  104       80     45      2      False
#  109       70     60      2      False
#  111       45     40      2      False
#  116       45     85      2      False
#  118       80     68      2      False
#  120       85    115      2      False
#  129      100     81      2      False
#  133       95     65      2      False
#  134       95    130      2      False
#  135      110     65      2      False
#  138       70     55      2      False
#  140       70     80      2      False
#  147       70     70      2      False  ,
#             Name    Type 1    Type 2  Total  HP  Attack  Defense  Sp. Atk  \
#  2      Venusaur     Grass    Poison    525  80      82       83      100
#  5     Charizard      Fire    Flying    534  78      84       78      109
#  8     Blastoise     Water       NaN    530  79      83      100       85
#  11   Butterfree       Bug    Flying    395  60      45       50       90
#  14     Beedrill       Bug    Poison    395  65      90       40       45
#  17      Pidgeot    Normal    Flying    479  83      80       75       70
#  30    Nidoqueen    Poison    Ground    505  90      92       87       75
#  33     Nidoking    Poison    Ground    505  81     102       77       85
#  44    Vileplume     Grass    Poison    490  75      80       85      110
#  61    Poliwrath     Water  Fighting    510  90      95       95       70
#  64     Alakazam   Psychic       NaN    500  55      50       45      135
#  67      Machamp  Fighting       NaN    505  90     130       80       65
#  70   Victreebel     Grass    Poison    490  80     105       65      100
#  75        Golem      Rock    Ground    495  80     120      130       55
#  93       Gengar     Ghost    Poison    500  60      65       60      130
#  148   Dragonite    Dragon    Flying    600  91     134       95      100
#
#       Sp. Def  Speed  Stage  Legendary
#  2        100     80      3      False
#  5         85    100      3      False
#  8        105     78      3      False
#  11        80     70      3      False
#  14        80     75      3      False
#  17        70    101      3      False
#  30        85     76      3      False
#  33        75     85      3      False
#  44        90     50      3      False
#  61        90     70      3      False
#  64        95    120      3      False
#  67        85     55      3      False
#  70        70     70      3      False
#  75        65     45      3      False
#  93        75    110      3      False
#  148      100     80      3      False  ]

# %%
# Now, edit the number of bins to 50, so we have greater granularity.
# Documentation: https://seaborn.pydata.org/generated/seaborn.distplot.html

# %%
# Only plot the Gaussian kernial density estimate (the line of the distribution) and the rugplot. What does this tell us?
# Documentation: https://seaborn.pydata.org/generated/seaborn.distplot.html

# %% [markdown]
# # Scatter plot

# %%
# Is attack positively or negatively correlated with defense? Use a scatterplot overlayed with a linear trendline to answer.
# Documentation: https://seaborn.pydata.org/generated/seaborn.lmplot.html

sns.lmplot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-22854a912293> in <module>
#       2 # Documentation: https://seaborn.pydata.org/generated/seaborn.lmplot.html
#       3
# ----> 4 sns.lmplot()
#
# TypeError: lmplot() missing 3 required positional arguments: 'x', 'y', and 'data'

# %% [markdown]
# # Correlation plot

# %%
# Calculate correlations between the variables. What do the black squares represent?
corr = poke_df.corr()
 
# Heatmap
sns.heatmap(corr,square=True);

# %%
# Go further to only highlight the negatively correlated variables by setting the color scale maximum to zero.
# Documentation: https://seaborn.pydata.org/generated/seaborn.heatmap.html
corr = poke_df.corr()
 
# Heatmap

# %% [markdown]
# # Boxplot

# %%
# Boxplot of the values of HP, Attack, and Defense
sns.boxplot(data=poke_df[['HP', 'Attack', 'Defense']])

# %%
# Plot a boxplot of Sp. Atk by each 'Stage.' Use the 'hue' parameter to separate 'Legendary' pokemon.

# %% [markdown]
# # Factor plot

# %%
# Factor Plot
g = sns.factorplot(x='Stage', 
                   y='Attack', 
                   data=poke_df, 
                   col='Legendary',
                   kind='swarm')
 
# Rotate x-axis labels
g.set_xticklabels(rotation=0)
# Out:
# C:\Users\raymi\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# # Violin factor plot

# %%
# Change the 'kind' of the factorplot to make a violin plot. How does this compare to the swarm plot?
# Out:
# C:\Users\raymi\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\raymi\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Add a hue parameter to make the color based on 'Legendary' instead of 'Stage'
# Out:
# C:\Users\raymi\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\raymi\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
